# %% [markdown]
# ## Fundamentals of Visualizations Part 2

# %% [markdown]
# #### Installing libraries and reading in data

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt
import seaborn as sns

# %%
df = pd.read_csv('NY_data_filtered.csv', index_col = 0)
# Out:
# C:\Users\marze\AppData\Local\Temp\ipykernel_25032\1100968856.py:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('NY_data_filtered.csv', index_col = 0)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
#
#                   ended_at       start_station_name start_station_id  \
# 0  2022-01-21 13:22:31.463  West End Ave & W 107 St          7650.05
# 1  2022-01-10 11:41:43.422             4 Ave & 3 St          4028.04
# 2  2022-01-26 11:06:35.227          1 Ave & E 62 St          6753.08
# 3  2022-01-03 09:10:50.475          2 Ave & E 96 St          7338.02
# 4  2022-01-22 14:34:57.474          6 Ave & W 34 St           6364.1
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0  Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# 1      Boerum Pl\t& Pacific St        4488.09  40.673746 -73.985649
# 2              5 Ave & E 29 St        6248.06  40.761227 -73.960940
# 3              5 Ave & E 29 St        6248.06  40.783964 -73.947167
# 4              5 Ave & E 29 St        6248.06  40.749640 -73.988050
#
#      end_lat    end_lng member_casual        date  avgTemp
# 0  40.804038 -73.945925        member  2022-01-21     -6.0
# 1  40.688489 -73.991160        member  2022-01-10      1.6
# 2  40.745168 -73.986831        member  2022-01-26     -2.3
# 3  40.745168 -73.986831        member  2022-01-03      1.4
# 4  40.745168 -73.986831        member  2022-01-22     -5.9

# %%
# Drop the 'start_station_id' and 'end_station_id' column 
df.drop(columns=['start_station_id','end_station_id'], inplace=True)

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
#
#                   ended_at       start_station_name  \
# 0  2022-01-21 13:22:31.463  West End Ave & W 107 St
# 1  2022-01-10 11:41:43.422             4 Ave & 3 St
# 2  2022-01-26 11:06:35.227          1 Ave & E 62 St
# 3  2022-01-03 09:10:50.475          2 Ave & E 96 St
# 4  2022-01-22 14:34:57.474          6 Ave & W 34 St
#
#               end_station_name  start_lat  start_lng    end_lat    end_lng  \
# 0  Mt Morris Park W & W 120 St  40.802117 -73.968181  40.804038 -73.945925
# 1      Boerum Pl\t& Pacific St  40.673746 -73.985649  40.688489 -73.991160
# 2              5 Ave & E 29 St  40.761227 -73.960940  40.745168 -73.986831
# 3              5 Ave & E 29 St  40.783964 -73.947167  40.745168 -73.986831
# 4              5 Ave & E 29 St  40.749640 -73.988050  40.745168 -73.986831
#
#   member_casual        date  avgTemp
# 0        member  2022-01-21     -6.0
# 1        member  2022-01-10      1.6
# 2        member  2022-01-26     -2.3
# 3        member  2022-01-03      1.4
# 4        member  2022-01-22     -5.9

# %%
df=df.sample(frac=.01)

# %%
df.head()
# Out:
#                    ride_id  rideable_type               started_at  \
# 16045531  0F030B54FA34313B   classic_bike  2022-08-20 09:26:57.192
# 29459241  AFF26D19E33066E2  electric_bike  2022-12-14 16:52:12.594
# 11012723  A4283244E8CEE84C  electric_bike  2022-06-28 12:35:20.491
# 29315650  D75F5366F9448E8E   classic_bike  2022-12-12 23:24:24.202
# 25460492  7B5919F75D0BBE87  electric_bike  2022-10-04 16:53:34.024
#
#                          ended_at        start_station_name  \
# 16045531  2022-08-20 09:29:57.984  W 104 St & Amsterdam Ave
# 29459241  2022-12-14 16:58:20.672           W 41 St & 8 Ave
# 11012723  2022-06-28 12:40:49.271        Broadway & E 19 St
# 29315650  2022-12-12 23:26:31.185   Stanton St & Norfolk St
# 25460492  2022-10-04 17:02:57.269           8 Ave & W 52 St
#
#                    end_station_name  start_lat  start_lng    end_lat  \
# 16045531  Central Park W & W 103 St  40.799041 -73.966495  40.795590
# 29459241    E 39 St & Lexington Ave  40.756405 -73.990026  40.749499
# 11012723            9 Ave & W 22 St  40.738661 -73.989873  40.745497
# 29315650    Rivington St & Ridge St  40.720747 -73.986274  40.718502
# 25460492            E 33 St & 5 Ave  40.764058 -73.985026  40.747659
#
#             end_lng member_casual        date  avgTemp
# 16045531 -73.961884        member  2022-08-20     27.9
# 29459241 -73.977292        casual  2022-12-14      1.7
# 11012723 -74.001971        member  2022-06-28     22.4
# 29315650 -73.983299        member  2022-12-12      1.6
# 25460492 -73.984907        member  2022-10-04     10.3

# %%
df.shape
# Out:
# (298382, 13)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# end_station_name       object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %% [markdown]
# #### Pick one theme and set it for all plots, and think of the style and the palette you want to use

# %%
# Set the theme for all plots
sns.set_style('white')
sns.set_palette('rainbow', n_colors=20)

# %% [markdown]
# #### Create a bar chart of the top 20 starting stations frequencies

# %%
df['value'] = 1

# %%
df_t = df.groupby('start_station_name')['value'].count().reset_index()

# %%
df_t
# Out:
#                 start_station_name  value
# 0                 1 Ave & E 110 St    238
# 1                  1 Ave & E 16 St    642
# 2                  1 Ave & E 18 St    687
# 3                  1 Ave & E 30 St    486
# 4                  1 Ave & E 39 St    526
# ...                            ...    ...
# 1717       Wyckoff Ave & Gates Ave    191
# 1718            Wyckoff St & 3 Ave      3
# 1719        Wyckoff St & Nevins St    116
# 1720  Wythe Ave & Metropolitan Ave    670
# 1721         Yankee Ferry Terminal    132
#
# [1722 rows x 2 columns]

# %%
top20 = df_t.nlargest(20, 'value')

# %%
top20
# Out:
#             start_station_name  value
# 1549           W 21 St & 6 Ave   1342
# 1679     West St & Chambers St   1299
# 485         Broadway & W 58 St   1159
# 283            6 Ave & W 33 St   1067
# 8              1 Ave & E 68 St   1018
# 451         Broadway & E 14 St    972
# 475         Broadway & W 25 St    961
# 1474   University Pl & E 14 St    961
# 453         Broadway & E 21 St    951
# 1565           W 31 St & 7 Ave    926
# 773            E 33 St & 1 Ave    919
# 781         E 40 St & Park Ave    905
# 284            6 Ave & W 34 St    898
# 24            11 Ave & W 41 St    890
# 29            12 Ave & W 40 St    888
# 578   Cleveland Pl & Spring St    881
# 332            9 Ave & W 22 St    869
# 1680      West St & Liberty St    863
# 324            8 Ave & W 33 St    856
# 551     Central Park S & 6 Ave    856

# %%
sns.barplot(data = top20, x = 'value', y = 'start_station_name')
plt.title("Most frequent start stations")
plt.show()

# %% [markdown]
# It seems that the color palette used in the previous plot makes sense and provides a clear visual distinction between the different frequency levels. However, to ensure that each bar is easily distinguishable and the palette contains enough colors, we can temporarily change the style of this specific plot.

# %%
sns.barplot(data = top20, x = 'value', y = 'start_station_name', palette = 'tab20')
plt.title("Most frequent start stations")
plt.show()

# %% [markdown]
# #### Recreate the dual-axis line plot from the previous Exercise using seaborn.

# %%
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')

# %%
# Groupby the count of the trips 

df_group = pd.DataFrame(df.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_group.head()
# Out:
#         date  ride_id
# 0 2022-01-01      199
# 1 2022-01-02      428
# 2 2022-01-03      313
# 3 2022-01-04      391
# 4 2022-01-05      351

# %%
df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)
df = df.merge(df_group, on = "date", how = 'outer', indicator = 'merge_flag')
print(df['merge_flag'].value_counts(dropna = False))
print("Shape of January 1st is", df[df['date'] == '2018-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2018-01-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# both          298382
# left_only          0
# right_only         0
# Name: merge_flag, dtype: int64
# Shape of January 1st is (0, 16)
# Shape of January 2nd is (0, 16)
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'end_station_name', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng', 'member_casual', 'avgTemp', 'value',
#        'bike_rides_daily', 'merge_flag'],
#       dtype='object')

# %%
df_temp.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'end_station_name', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng', 'member_casual', 'avgTemp', 'value',
#        'bike_rides_daily', 'merge_flag'],
#       dtype='object')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type               started_at  \
# date
# 2022-08-20  0F030B54FA34313B   classic_bike  2022-08-20 09:26:57.192
# 2022-08-20  BBEF4E56E71DD92A  electric_bike  2022-08-20 16:26:32.519
# 2022-08-20  58E78C85894BBEB6   classic_bike  2022-08-20 10:19:46.012
# 2022-08-20  6E6A8954757E3728   classic_bike  2022-08-20 12:19:40.318
# 2022-08-20  7B0B0DE2AFA1EE8C   classic_bike  2022-08-20 14:35:57.627
#
#                            ended_at        start_station_name  \
# date
# 2022-08-20  2022-08-20 09:29:57.984  W 104 St & Amsterdam Ave
# 2022-08-20  2022-08-20 16:30:21.727           8 Ave & W 33 St
# 2022-08-20  2022-08-20 11:32:51.960  Lexington Ave & E 111 St
# 2022-08-20  2022-08-20 12:30:36.711           4 Ave & E 12 St
# 2022-08-20  2022-08-20 14:49:13.863        Broadway & W 25 St
#
#                      end_station_name  start_lat  start_lng    end_lat  \
# date
# 2022-08-20  Central Park W & W 103 St  40.799041 -73.966495  40.795590
# 2022-08-20   W 34 St &\tHudson Blvd E  40.751661 -73.993754  40.755167
# 2022-08-20       Centre St & Worth St  40.795412 -73.944123  40.714948
# 2022-08-20   Howard St & Lafayette St  40.732647 -73.990110  40.719105
# 2022-08-20  Gansevoort St & Hudson St  40.742869 -73.989186  40.739448
#
#               end_lng member_casual  avgTemp  value  bike_rides_daily  \
# date
# 2022-08-20 -73.961884        member     27.9      1              1245
# 2022-08-20 -74.000599        casual     27.9      1              1245
# 2022-08-20 -74.002345        casual     27.9      1              1245
# 2022-08-20 -73.999733        member     27.9      1              1245
# 2022-08-20 -74.005070        member     27.9      1              1245
#
#            merge_flag
# date
# 2022-08-20       both
# 2022-08-20       both
# 2022-08-20       both
# 2022-08-20       both
# 2022-08-20       both

# %%
# Drop the 'merge_flag' column 
df_temp.drop(columns='merge_flag', inplace=True)

# %%
df_temp.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'end_station_name', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng', 'member_casual', 'avgTemp', 'value',
#        'bike_rides_daily'],
#       dtype='object')

# %%
fig,ax = plt.subplots(figsize=(15, 5))
sns.lineplot(data = df_temp['bike_rides_daily'], color = "b")
ax.set_xlabel("Year 2022", fontsize = 14) # set x-axis label
ax.set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

ax2 = ax.twinx()
sns.lineplot(data = df_temp['avgTemp'], color="r", ax=ax2)
ax2.set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.title('Temperature and trips in 2022', fontsize = 18)
plt.show()

# %% [markdown]
# #### Make a box plot of one of the categorical variables in data set.

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# end_station_name              object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# value                          int64
# bike_rides_daily               int64
# merge_flag                  category
# dtype: object

# %%
# Drop the 'merge_flag' column 
df.drop(columns='merge_flag', inplace=True)

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# end_station_name              object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# value                          int64
# bike_rides_daily               int64
# dtype: object

# %%
df['member_casual']
# Out:
# 0         member
# 1         casual
# 2         casual
# 3         member
# 4         member
#            ...
# 298377    member
# 298378    casual
# 298379    member
# 298380    member
# 298381    member
# Name: member_casual, Length: 298382, dtype: object

# %%
plt.figure(figsize=(9,5))
sns.boxplot(x = 'member_casual', y='bike_rides_daily', data=df, palette={'member': 'skyblue', 'casual': 'lightcoral'})

# Customize the axis labels
plt.title('Box Plot of Ride Duration by Membership Type', fontsize=18)
plt.xlabel('Membership Type', fontsize=14)
plt.ylabel('Ride Duration (minutes)', fontsize=14)
plt.savefig('box_plot_member_trip_duration.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
plt.show()

# %% [markdown]
# The y-axis represents the number of bike rides daily, ranging from 0 to 1400. The box plot for members shows a median daily bike ride count of around 1000, with the interquartile range (IQR) spanning from approximately 800 to 1200. The box plot for casual users also has a median around 1000, but the IQR is slightly wider, ranging from about 600 to 1200. Additionally, the casual user group has more outliers below the lower whisker, indicating a greater variability in the lower range of daily bike rides compared to the member group. This plot is interesting as it highlights the distribution and variability of bike rides between members and casual users, which can be useful for understanding user behavior and planning bike-sharing services.

# %% [markdown]
# #### Create a FacetGrid and write 2 to 3 sentences analyzing what insight its output brings.

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'end_station_name', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng', 'member_casual', 'date', 'avgTemp', 'value',
#        'bike_rides_daily'],
#       dtype='object')

# %%
# Convert 'started_at' and 'ended_at' to datetime
df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])

# Calculate the trip duration in minutes
df['trip_duration'] = (df['ended_at'] - df['started_at']).dt.total_seconds() / 60

# Verify that the 'tripduration' column has been created successfully
df[['started_at', 'ended_at', 'trip_duration']]
# Out:
#                     started_at                ended_at  trip_duration
# 0      2022-08-20 09:26:57.192 2022-08-20 09:29:57.984       3.013200
# 1      2022-08-20 16:26:32.519 2022-08-20 16:30:21.727       3.820133
# 2      2022-08-20 10:19:46.012 2022-08-20 11:32:51.960      73.099133
# 3      2022-08-20 12:19:40.318 2022-08-20 12:30:36.711      10.939883
# 4      2022-08-20 14:35:57.627 2022-08-20 14:49:13.863      13.270600
# ...                        ...                     ...            ...
# 298377 2022-01-29 12:59:15.761 2022-01-29 13:02:49.849       3.568133
# 298378 2022-01-29 15:04:00.041 2022-01-29 15:16:36.060      12.600317
# 298379 2022-01-29 18:36:56.160 2022-01-29 18:57:14.247      20.301450
# 298380 2022-01-29 21:20:06.198 2022-01-29 21:29:29.154       9.382600
# 298381 2022-01-29 19:35:50.563 2022-01-29 20:55:00.726      79.169383
#
# [298382 rows x 3 columns]

# %%
#Remove outliers in 'trip_duration'
#Calculate the IQR
Q1 = df['trip_duration'].quantile(0.25)
Q3 = df['trip_duration'].quantile(0.75)
IQR = Q3 - Q1

# Filter the DataFrame to remove outliers
df_filtered = df[(df['trip_duration'] >= (Q1 - 1.5 * IQR)) & (df['trip_duration'] <= (Q3 + 1.5 * IQR))]

# %%
df_filtered
# Out:
#                  ride_id  rideable_type              started_at  \
# 0       0F030B54FA34313B   classic_bike 2022-08-20 09:26:57.192
# 1       BBEF4E56E71DD92A  electric_bike 2022-08-20 16:26:32.519
# 3       6E6A8954757E3728   classic_bike 2022-08-20 12:19:40.318
# 4       7B0B0DE2AFA1EE8C   classic_bike 2022-08-20 14:35:57.627
# 5       FFADCB7B0092C521  electric_bike 2022-08-20 08:29:45.420
# ...                  ...            ...                     ...
# 298376  BF0B79BB14834EF0   classic_bike 2022-01-29 01:17:20.542
# 298377  AAFD02A70A4D9DCE   classic_bike 2022-01-29 12:59:15.761
# 298378  07D8FFF86B73B7E5   classic_bike 2022-01-29 15:04:00.041
# 298379  330AC9C8B44CA056  electric_bike 2022-01-29 18:36:56.160
# 298380  073696C0D7F9E61F  electric_bike 2022-01-29 21:20:06.198
#
#                       ended_at        start_station_name  \
# 0      2022-08-20 09:29:57.984  W 104 St & Amsterdam Ave
# 1      2022-08-20 16:30:21.727           8 Ave & W 33 St
# 3      2022-08-20 12:30:36.711           4 Ave & E 12 St
# 4      2022-08-20 14:49:13.863        Broadway & W 25 St
# 5      2022-08-20 08:31:07.053         E 5 St & Avenue C
# ...                        ...                       ...
# 298376 2022-01-29 01:25:36.509           8 Ave & W 52 St
# 298377 2022-01-29 13:02:49.849           1 Ave & E 78 St
# 298378 2022-01-29 15:16:36.060  Howard St & Lafayette St
# 298379 2022-01-29 18:57:14.247        W 35 St & Dyer Ave
# 298380 2022-01-29 21:29:29.154       Broadway\t& W 48 St
#
#                  end_station_name  start_lat  start_lng    end_lat    end_lng  \
# 0       Central Park W & W 103 St  40.799041 -73.966495  40.795590 -73.961884
# 1        W 34 St &\tHudson Blvd E  40.751661 -73.993754  40.755167 -74.000599
# 3        Howard St & Lafayette St  40.732647 -73.990110  40.719105 -73.999733
# 4       Gansevoort St & Hudson St  40.742869 -73.989186  40.739448 -74.005070
# 5               E 2 St & Avenue B  40.722985 -73.980030  40.722174 -73.983688
# ...                           ...        ...        ...        ...        ...
# 298376    E 53 St & Lexington Ave  40.763707 -73.985162  40.758281 -73.970694
# 298377            E 81 St & 2 Ave  40.771404 -73.953517  40.774779 -73.954275
# 298378     Perry St & Bleecker St  40.719105 -73.999733  40.735354 -74.004831
# 298379            W 18 St & 9 Ave  40.754692 -73.997402  40.743534 -74.003676
# 298380     W 74 St & Columbus Ave  40.760177 -73.984868  40.778567 -73.977550
#
#        member_casual       date  avgTemp  value  bike_rides_daily  \
# 0             member 2022-08-20     27.9      1              1245
# 1             casual 2022-08-20     27.9      1              1245
# 3             member 2022-08-20     27.9      1              1245
# 4             member 2022-08-20     27.9      1              1245
# 5             member 2022-08-20     27.9      1              1245
# ...              ...        ...      ...    ...               ...
# 298376        member 2022-01-29     -4.8      1                20
# 298377        member 2022-01-29     -4.8      1                20
# 298378        casual 2022-01-29     -4.8      1                20
# 298379        member 2022-01-29     -4.8      1                20
# 298380        member 2022-01-29     -4.8      1                20
#
#         trip_duration
# 0            3.013200
# 1            3.820133
# 3           10.939883
# 4           13.270600
# 5            1.360550
# ...               ...
# 298376       8.266117
# 298377       3.568133
# 298378      12.600317
# 298379      20.301450
# 298380       9.382600
#
# [279453 rows x 16 columns]

# %%
# Create a FacetGrid plot to visualize the distribution of trip duration by membership type and rideable type
grid= sns.FacetGrid(df_filtered, col='member_casual', row='rideable_type', margin_titles=True, height=3, aspect=1.5)
grid.map(sns.histplot, 'trip_duration', bins=10, kde=True, color='skyblue')

# Add titles, labels, and adjust layout
grid.set_axis_labels('Trip Duration (minutes)', 'Frequency')
grid.set_titles(col_template='{col_name}', row_template='{row_name}')
grid.fig.suptitle('Distribution of Trip Duration by Membership Type and Rideable Type', fontsize=16)
grid.fig.subplots_adjust(top=0.9)

plt.show()

# %% [markdown]
# The FacetGrid plot reveals distinct patterns in trip durations based on membership type and rideable type. For members using both classic and electric bikes, shorter trip durations are more common, indicating that members may prefer quick commutes. On the other hand, casual users show a more varied distribution of trip durations, especially with electric bikes, which suggests that they might be using the service for a broader range of activities, including leisure and exploration.

# %% [markdown]
# #### Saving the plots and Exporting the new updated dataframe

# %%
# save the dual axis plot as a file
fig.savefig('trips_temperatures_dual_line_sns.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
grid.savefig('trips_membership_bike_type.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
# save the wrangled sample data
df.to_csv('NY_data_sample.csv')
