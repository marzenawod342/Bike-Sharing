# %% [markdown]
# ## Fundamentals of Visualizations Part 2

# %% [markdown]
# #### Installing libraries and reading in data

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt
import seaborn as sns

# %%
df = pd.read_csv('NY_data_filtered.csv', index_col = 0)
# Out:
# C:\Users\marze\AppData\Local\Temp\ipykernel_9144\1100968856.py:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('NY_data_filtered.csv', index_col = 0)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
#
#                   ended_at       start_station_name start_station_id  \
# 0  2022-01-21 13:22:31.463  West End Ave & W 107 St          7650.05
# 1  2022-01-10 11:41:43.422             4 Ave & 3 St          4028.04
# 2  2022-01-26 11:06:35.227          1 Ave & E 62 St          6753.08
# 3  2022-01-03 09:10:50.475          2 Ave & E 96 St          7338.02
# 4  2022-01-22 14:34:57.474          6 Ave & W 34 St           6364.1
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0  Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# 1      Boerum Pl\t& Pacific St        4488.09  40.673746 -73.985649
# 2              5 Ave & E 29 St        6248.06  40.761227 -73.960940
# 3              5 Ave & E 29 St        6248.06  40.783964 -73.947167
# 4              5 Ave & E 29 St        6248.06  40.749640 -73.988050
#
#      end_lat    end_lng member_casual        date  avgTemp
# 0  40.804038 -73.945925        member  2022-01-21     -6.0
# 1  40.688489 -73.991160        member  2022-01-10      1.6
# 2  40.745168 -73.986831        member  2022-01-26     -2.3
# 3  40.745168 -73.986831        member  2022-01-03      1.4
# 4  40.745168 -73.986831        member  2022-01-22     -5.9

# %%
# Drop the 'start_station_id' and 'end_station_id' column 
df.drop(columns=['start_station_id','end_station_id'], inplace=True)

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
#
#                   ended_at       start_station_name  \
# 0  2022-01-21 13:22:31.463  West End Ave & W 107 St
# 1  2022-01-10 11:41:43.422             4 Ave & 3 St
# 2  2022-01-26 11:06:35.227          1 Ave & E 62 St
# 3  2022-01-03 09:10:50.475          2 Ave & E 96 St
# 4  2022-01-22 14:34:57.474          6 Ave & W 34 St
#
#               end_station_name  start_lat  start_lng    end_lat    end_lng  \
# 0  Mt Morris Park W & W 120 St  40.802117 -73.968181  40.804038 -73.945925
# 1      Boerum Pl\t& Pacific St  40.673746 -73.985649  40.688489 -73.991160
# 2              5 Ave & E 29 St  40.761227 -73.960940  40.745168 -73.986831
# 3              5 Ave & E 29 St  40.783964 -73.947167  40.745168 -73.986831
# 4              5 Ave & E 29 St  40.749640 -73.988050  40.745168 -73.986831
#
#   member_casual        date  avgTemp
# 0        member  2022-01-21     -6.0
# 1        member  2022-01-10      1.6
# 2        member  2022-01-26     -2.3
# 3        member  2022-01-03      1.4
# 4        member  2022-01-22     -5.9

# %%
df=df.sample(frac=.01)

# %%
df.head()
# Out:
#                   ride_id  rideable_type               started_at  \
# 8977067  93A06546A58731E9   classic_bike  2022-05-15 13:13:58.191
# 8161097  9CA02B966A4748B2  electric_bike  2022-05-31 10:06:49.318
# 6379359  8B8E4A9D6F16EDF3  electric_bike  2022-05-19 17:17:27.955
# 5880897  7064AD765410916F  electric_bike  2022-04-10 03:57:46.688
# 1034499  DBC5EDBEF61A339B   classic_bike  2022-02-26 16:37:45.162
#
#                         ended_at         start_station_name  \
# 8977067  2022-05-15 13:35:24.663           W 46 St & 11 Ave
# 8161097  2022-05-31 10:14:28.746             31 St & 23 Ave
# 6379359  2022-05-19 17:23:08.647        Broadway\t& W 48 St
# 5880897  2022-04-10 04:12:00.372    Grand St & Elizabeth St
# 1034499  2022-02-26 16:47:20.243  Thompson St & Bleecker St
#
#               end_station_name  start_lat  start_lng    end_lat    end_lng  \
# 8977067       10 Ave & W 14 St  40.763414 -73.996674  40.741982 -74.008316
# 8161097          21 St & 31 Dr  40.774788 -73.912555  40.765900 -73.930819
# 6379359        6 Ave & W 34 St  40.760177 -73.984868  40.749640 -73.988050
# 5880897    White St & Moore St  40.718822 -73.995960  40.704508 -73.935100
# 1034499  Allen St & Stanton St  40.728401 -73.999688  40.722055 -73.989111
#
#         member_casual        date  avgTemp
# 8977067        member  2022-05-15     18.8
# 8161097        member  2022-05-31     28.3
# 6379359        member  2022-05-19     15.5
# 5880897        member  2022-04-10      8.6
# 1034499        casual  2022-02-26     -1.1

# %%
df.shape
# Out:
# (103809, 13)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# end_station_name       object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %% [markdown]
# #### Pick one theme and set it for all plots, and think of the style and the palette you want to use

# %%
# Set the theme for all plots
sns.set_style('white')
sns.set_palette('rainbow', n_colors=20)

# %% [markdown]
# #### Create a bar chart of the top 20 starting stations frequencies

# %%
df['value'] = 1

# %%
df_t = df.groupby('start_station_name')['value'].count().reset_index()

# %%
df_t
# Out:
#                 start_station_name  value
# 0                 1 Ave & E 110 St     78
# 1                  1 Ave & E 16 St    273
# 2                  1 Ave & E 18 St    265
# 3                  1 Ave & E 30 St    147
# 4                  1 Ave & E 39 St    225
# ...                            ...    ...
# 1565      Wyckoff Av & Stanhope St     53
# 1566       Wyckoff Ave & Gates Ave     44
# 1567        Wyckoff St & Nevins St     56
# 1568  Wythe Ave & Metropolitan Ave    225
# 1569         Yankee Ferry Terminal     23
#
# [1570 rows x 2 columns]

# %%
top20 = df_t.nlargest(20, 'value')

# %%
top20
# Out:
#                      start_station_name  value
# 1407                    W 21 St & 6 Ave    445
# 1532              West St & Chambers St    413
# 8                       1 Ave & E 68 St    402
# 387                  Broadway & E 14 St    398
# 419                  Broadway & W 58 St    392
# 242                     6 Ave & W 33 St    373
# 389                  Broadway & E 21 St    362
# 410                  Broadway & W 25 St    345
# 481              Central Park S & 6 Ave    336
# 1336            University Pl & E 14 St    336
# 1422                    W 31 St & 7 Ave    336
# 697                     E 33 St & 1 Ave    328
# 29                     12 Ave & W 40 St    326
# 1533               West St & Liberty St    323
# 862   Grand Army Plaza & Central Park S    321
# 267                     8 Ave & W 31 St    316
# 452                  Carmine St & 6 Ave    315
# 243                     6 Ave & W 34 St    310
# 504            Cleveland Pl & Spring St    310
# 268                     8 Ave & W 33 St    307

# %%
sns.barplot(data = top20, x = 'value', y = 'start_station_name')
plt.title("Most frequent start stations")
plt.show()

# %% [markdown]
# It seems that the color palette used in the previous plot makes sense and provides a clear visual distinction between the different frequency levels. However, to ensure that each bar is easily distinguishable and the palette contains enough colors, we can temporarily change the style of this specific plot.

# %%
sns.barplot(data = top20, x = 'value', y = 'start_station_name', palette = 'tab20')
plt.title("Most frequent start stations")
plt.show()

# %% [markdown]
# #### Recreate the dual-axis line plot from the previous Exercise using seaborn.

# %%
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')

# %%
# Groupby the count of the trips 

df_group = pd.DataFrame(df.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_group.head()
# Out:
#         date  ride_id
# 0 2022-01-01      199
# 1 2022-01-02      486
# 2 2022-01-03      328
# 3 2022-01-04      339
# 4 2022-01-05      320

# %%
df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)
df = df.merge(df_group, on = "date", how = 'outer', indicator = 'merge_flag')
print(df['merge_flag'].value_counts(dropna = False))
print("Shape of January 1st is", df[df['date'] == '2018-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2018-01-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# both          103809
# left_only          0
# right_only         0
# Name: merge_flag, dtype: int64
# Shape of January 1st is (0, 16)
# Shape of January 2nd is (0, 16)
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'end_station_name', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng', 'member_casual', 'avgTemp', 'value',
#        'bike_rides_daily', 'merge_flag'],
#       dtype='object')

# %%
df_temp.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'end_station_name', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng', 'member_casual', 'avgTemp', 'value',
#        'bike_rides_daily', 'merge_flag'],
#       dtype='object')

# %%
df_temp.head()
# Out:
#                      ride_id rideable_type               started_at  \
# date
# 2022-05-15  93A06546A58731E9  classic_bike  2022-05-15 13:13:58.191
# 2022-05-15  803709218EBC2E16  classic_bike  2022-05-15 16:54:56.416
# 2022-05-15  FC6C2287D6934255  classic_bike  2022-05-15 15:44:58.147
# 2022-05-15  6F54A3D5C6611E26  classic_bike  2022-05-15 09:25:49.747
# 2022-05-15  A812F3A553CB0B3B  classic_bike  2022-05-15 19:35:27.411
#
#                            ended_at        start_station_name  \
# date
# 2022-05-15  2022-05-15 13:35:24.663          W 46 St & 11 Ave
# 2022-05-15  2022-05-15 17:39:53.927         12 Ave & W 125 St
# 2022-05-15  2022-05-15 15:57:02.553  Atlantic Ave & Furman St
# 2022-05-15  2022-05-15 09:54:04.091           W 39 St & 9 Ave
# 2022-05-15  2022-05-15 19:41:16.179  Riverside Blvd & W 67 St
#
#                    end_station_name  start_lat  start_lng    end_lat  \
# date
# 2022-05-15         10 Ave & W 14 St  40.763414 -73.996674  40.741982
# 2022-05-15  Riverside Dr & W 104 St  40.818299 -73.960405  40.801343
# 2022-05-15    Coffey St & Ferris St  40.691652 -73.999979  40.678184
# 2022-05-15          E 58 St & 3 Ave  40.756458 -73.993722  40.760958
# 2022-05-15   Riverside Dr & W 78 St  40.777507 -73.988886  40.784145
#
#               end_lng member_casual  avgTemp  value  bike_rides_daily  \
# date
# 2022-05-15 -74.008316        member     18.8      1              1133
# 2022-05-15 -73.971146        member     18.8      1              1133
# 2022-05-15 -74.017017        casual     18.8      1              1133
# 2022-05-15 -73.967245        casual     18.8      1              1133
# 2022-05-15 -73.983625        member     18.8      1              1133
#
#            merge_flag
# date
# 2022-05-15       both
# 2022-05-15       both
# 2022-05-15       both
# 2022-05-15       both
# 2022-05-15       both

# %%
# Drop the 'merge_flag' column 
df_temp.drop(columns='merge_flag', inplace=True)

# %%
df_temp.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'end_station_name', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng', 'member_casual', 'avgTemp', 'value',
#        'bike_rides_daily'],
#       dtype='object')

# %%
fig,ax = plt.subplots(figsize=(15, 5))
sns.lineplot(data = df_temp['bike_rides_daily'], color = "b")
ax.set_xlabel("Year 2022", fontsize = 14) # set x-axis label
ax.set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

ax2 = ax.twinx()
sns.lineplot(data = df_temp['avgTemp'], color="r", ax=ax2)
ax2.set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.title('Temperature and trips in 2022', fontsize = 18)
plt.show()

# %% [markdown]
# #### Make a box plot of one of the categorical variables in data set.

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# end_station_name              object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# value                          int64
# bike_rides_daily               int64
# merge_flag                  category
# dtype: object

# %%
# Drop the 'merge_flag' column 
df.drop(columns='merge_flag', inplace=True)

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# end_station_name              object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# value                          int64
# bike_rides_daily               int64
# dtype: object

# %%
df['member_casual']
# Out:
# 0         member
# 1         member
# 2         casual
# 3         casual
# 4         member
#            ...
# 103804    casual
# 103805    member
# 103806    member
# 103807    member
# 103808    member
# Name: member_casual, Length: 103809, dtype: object

# %%
plt.figure(figsize=(9,5))
sns.boxplot(x = 'member_casual', y='bike_rides_daily', data=df, palette={'member': 'skyblue', 'casual': 'lightcoral'})

# Customize the axis labels
plt.title('Box Plot of Ride Duration by Membership Type', fontsize=18)
plt.xlabel('Membership Type', fontsize=14)
plt.ylabel('Ride Duration (minutes)', fontsize=14)
plt.savefig('box_plot_member_trip_duration.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
plt.show()

# %% [markdown]
# The y-axis represents the number of bike rides daily, ranging from 0 to 1400. The box plot for members shows a median daily bike ride count of around 1000, with the interquartile range (IQR) spanning from approximately 800 to 1200. The box plot for casual users also has a median around 1000, but the IQR is slightly wider, ranging from about 600 to 1200. Additionally, the casual user group has more outliers below the lower whisker, indicating a greater variability in the lower range of daily bike rides compared to the member group. This plot is interesting as it highlights the distribution and variability of bike rides between members and casual users, which can be useful for understanding user behavior and planning bike-sharing services.

# %% [markdown]
# #### Create a FacetGrid and write 2 to 3 sentences analyzing what insight its output brings.

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'end_station_name', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng', 'member_casual', 'date', 'avgTemp', 'value',
#        'bike_rides_daily'],
#       dtype='object')

# %%
# Convert 'started_at' and 'ended_at' to datetime
df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])

# Calculate the trip duration in minutes
df['trip_duration'] = (df['ended_at'] - df['started_at']).dt.total_seconds() / 60

# Verify that the 'tripduration' column has been created successfully
df[['started_at', 'ended_at', 'trip_duration']]
# Out:
#                     started_at                ended_at  trip_duration
# 0      2022-05-15 13:13:58.191 2022-05-15 13:35:24.663      21.441200
# 1      2022-05-15 16:54:56.416 2022-05-15 17:39:53.927      44.958517
# 2      2022-05-15 15:44:58.147 2022-05-15 15:57:02.553      12.073433
# 3      2022-05-15 09:25:49.747 2022-05-15 09:54:04.091      28.239067
# 4      2022-05-15 19:35:27.411 2022-05-15 19:41:16.179       5.812800
# ...                        ...                     ...            ...
# 103804 2022-01-30 12:54:37.221 2022-01-30 13:00:46.807       6.159767
# 103805 2022-01-30 08:45:06.878 2022-01-30 08:52:04.719       6.964017
# 103806 2022-01-30 14:56:19.740 2022-01-30 15:17:11.446      20.861767
# 103807 2022-01-30 20:52:32.681 2022-01-30 21:02:10.859       9.636300
# 103808 2022-01-30 21:09:38.743 2022-01-30 21:11:32.135       1.889867
#
# [103809 rows x 3 columns]

# %%
#Remove outliers in 'trip_duration'
#Calculate the IQR
Q1 = df['trip_duration'].quantile(0.25)
Q3 = df['trip_duration'].quantile(0.75)
IQR = Q3 - Q1

# Filter the DataFrame to remove outliers
df_filtered = df[(df['trip_duration'] >= (Q1 - 1.5 * IQR)) & (df['trip_duration'] <= (Q3 + 1.5 * IQR))]

# %%
df_filtered
# Out:
#                  ride_id  rideable_type              started_at  \
# 0       93A06546A58731E9   classic_bike 2022-05-15 13:13:58.191
# 2       FC6C2287D6934255   classic_bike 2022-05-15 15:44:58.147
# 3       6F54A3D5C6611E26   classic_bike 2022-05-15 09:25:49.747
# 4       A812F3A553CB0B3B   classic_bike 2022-05-15 19:35:27.411
# 5       D91C05AC00E1C496  electric_bike 2022-05-15 14:04:18.464
# ...                  ...            ...                     ...
# 103804  38FA40FE46FEE079  electric_bike 2022-01-30 12:54:37.221
# 103805  2F9473BBFD5B161B   classic_bike 2022-01-30 08:45:06.878
# 103806  2176A9E843FFDD1D  electric_bike 2022-01-30 14:56:19.740
# 103807  F32F314FA0942863  electric_bike 2022-01-30 20:52:32.681
# 103808  ADD271CF39ABFE5C  electric_bike 2022-01-30 21:09:38.743
#
#                       ended_at                  start_station_name  \
# 0      2022-05-15 13:35:24.663                    W 46 St & 11 Ave
# 2      2022-05-15 15:57:02.553            Atlantic Ave & Furman St
# 3      2022-05-15 09:54:04.091                     W 39 St & 9 Ave
# 4      2022-05-15 19:41:16.179            Riverside Blvd & W 67 St
# 5      2022-05-15 14:09:01.254           Graham Ave & Conselyea St
# ...                        ...                                 ...
# 103804 2022-01-30 13:00:46.807         Montrose Ave & Bushwick Ave
# 103805 2022-01-30 08:52:04.719                    E 116 St & 2 Ave
# 103806 2022-01-30 15:17:11.446  Frederick Douglass Blvd & W 112 St
# 103807 2022-01-30 21:02:10.859                 Hudson St & W 13 St
# 103808 2022-01-30 21:11:32.135                     W 13 St & 5 Ave
#
#                    end_station_name  start_lat  start_lng    end_lat  \
# 0                  10 Ave & W 14 St  40.763414 -73.996674  40.741982
# 2             Coffey St & Ferris St  40.691652 -73.999979  40.678184
# 3                   E 58 St & 3 Ave  40.756458 -73.993722  40.760958
# 4            Riverside Dr & W 78 St  40.777507 -73.988886  40.784145
# 5         Manhattan Av & Leonard St  40.715143 -73.944507  40.720840
# ...                             ...        ...        ...        ...
# 103804   Richardson St & N Henry St  40.707678 -73.940162  40.719079
# 103805  Mt Morris Park W & W 120 St  40.796879 -73.937261  40.804038
# 103806           Broadway & W 58 St  40.801694 -73.957145  40.766953
# 103807          St Marks Pl & 1 Ave  40.740057 -74.005274  40.727791
# 103808           Broadway & E 14 St  40.735445 -73.994310  40.734546
#
#           end_lng member_casual       date  avgTemp  value  bike_rides_daily  \
# 0      -74.008316        member 2022-05-15     18.8      1              1133
# 2      -74.017017        casual 2022-05-15     18.8      1              1133
# 3      -73.967245        casual 2022-05-15     18.8      1              1133
# 4      -73.983625        member 2022-05-15     18.8      1              1133
# 5      -73.948440        member 2022-05-15     18.8      1              1133
# ...           ...           ...        ...      ...    ...               ...
# 103804 -73.942237        casual 2022-01-30     -7.1      1                94
# 103805 -73.945925        member 2022-01-30     -7.1      1                94
# 103806 -73.981693        member 2022-01-30     -7.1      1                94
# 103807 -73.985649        member 2022-01-30     -7.1      1                94
# 103808 -73.990741        member 2022-01-30     -7.1      1                94
#
#         trip_duration
# 0           21.441200
# 2           12.073433
# 3           28.239067
# 4            5.812800
# 5            4.713167
# ...               ...
# 103804       6.159767
# 103805       6.964017
# 103806      20.861767
# 103807       9.636300
# 103808       1.889867
#
# [97260 rows x 16 columns]

# %%
# Create a FacetGrid plot to visualize the distribution of trip duration by membership type and rideable type
grid= sns.FacetGrid(df_filtered, col='member_casual', row='rideable_type', margin_titles=True, height=3, aspect=1.5)
grid.map(sns.histplot, 'trip_duration', bins=10, kde=True, color='skyblue')

# Add titles, labels, and adjust layout
grid.set_axis_labels('Trip Duration (minutes)', 'Frequency')
grid.set_titles(col_template='{col_name}', row_template='{row_name}')
grid.fig.suptitle('Distribution of Trip Duration by Membership Type and Rideable Type', fontsize=16)
grid.fig.subplots_adjust(top=0.9)

plt.show()

# %% [markdown]
# The FacetGrid plot reveals distinct patterns in trip durations based on membership type and rideable type. For members using both classic and electric bikes, shorter trip durations are more common, indicating that members may prefer quick commutes. On the other hand, casual users show a more varied distribution of trip durations, especially with electric bikes, which suggests that they might be using the service for a broader range of activities, including leisure and exploration.

# %% [markdown]
# #### Saving the plots and Exporting the new updated dataframe

# %%
# save the dual axis plot as a file
fig.savefig('trips_temperatures_dual_line_sns.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
grid.savefig('trips_membership_bike_type.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
# save the wrangled sample data
df.to_csv('NY_data_sample.csv')
